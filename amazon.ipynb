# %%
import requests
import json
from bs4 import BeautifulSoup

# 正則表達式用
import re

# %%
def sleeptime(hour,min,sec):
    return hour*3600 + min*60 + sec;

# %% [markdown]
# ### 使用 agent

# %%
url = "https://www.amazon.com/s?k=iphone+11+case&__mk_zh_CN=%E4%BA%9A%E9%A9%AC%E9%80%8A%E7%BD%91%E7%AB%99&crid=9CGIUROCEYMH&sprefix=iph%2Caps%2C389&ref=nb_sb_noss_2"
head = {
    'User-Agent': 'Mozilla/5.0',
}
cookie = { "aws-priv":"eyJ2IjoxLCJldSI6MCwic3QiOjB9",
            "aws-target-static-id":"1587569651066-970706",
            "aws-target-data":"%7B%22support%22%3A%221%22%7D",
            "s_fid":"7578A7B9AE9A271E-351A1FB688F37844",
            "regStatus":"pre-register",
            "session-id":"145-1968745-9117905",
            "session-id-time":"2082787201l",
            "ubid-main":"133-9739132-8321040",
            "x-wl-uid":"1wK8h4AyfHZohWVMDWucP3tea2HjGuMvXVbkRvCR0UXrFtw7fdvQIeIf4PdGLe9453YhuZPsfZno=",
            "session-token":"",
            "aws_lang":"tw",
            "s_vn":"1619105651863%26vn%3D2",
            "s_cc":"true",
            "aws-target-visitor-id":"1587569651072-367053.32_0",
            "s_dslv":"1591516391701",
            "s_nr":"1591516391707-Repeat",
            "lc-main":"zh_CN",
            "i18n-prefs":"TWD",
            "skin":"noskin",
            "csm-hit":"tb:PR61NHATNA7CM3CFXWN3+b-CADZZMYFPXGSN0FFZ7R4|1591519308998&t:1591519308999&adb:adblk_yes",}
proxy_id = { "http": "http://61.135.155.82:443"}
response = requests.get(url, headers=head, proxies=proxy_id, cookies=cookie)
response.encoding = response.apparent_encoding

# %%
print(response.status_code, response.history, response.url)
# Out:
# 200 [] https://www.amazon.com/s?k=iphone+11+case&__mk_zh_CN=%E4%BA%9A%E9%A9%AC%E9%80%8A%E7%BD%91%E7%AB%99&crid=9CGIUROCEYMH&sprefix=iph%2Caps%2C389&ref=nb_sb_noss_2

# %%
print(response.text)
# Out:
# <!doctype html><html lang="zh-cn" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
#
# <script type='text/javascript'>var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:feature:cs-optimization -->
# <meta http-equiv='x-dns-prefetch-control' content='on'>
# <link rel="dns-prefetch" href="https://images-na.ssl-images-amazon.com" crossorigin>
# <link rel="preconnect" href="https://images-na.ssl-images-amazon.com" crossorigin>
# <link rel="dns-prefetch" href="https://m.media-amazon.com" crossorigin>
# <link rel="preconnect" href="https://m.media-amazon.com" crossorigin>
# <link rel="dns-prefetch" href="https://completion.amazon.com" crossorigin>
# <link rel="preconnect" href="https://completion.amazon.com" crossorigin>
# <script type='text/javascript'>
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
# ...

# %%
soup = BeautifulSoup(response.text, "lxml")
i = 0
for item in soup.select("span.a-size-medium.a-color-base.a-text-normal"):
    if (i>2):
        break
    print(item.text)
    i += 1

# %% [markdown]
# ### headers, cookies 為必要
# 發送大量 get 可能需要 proxy

# %%
url = "https://www.amazon.com/s?k=iphone+11+case&ref=nb_sb_noss"
head = {
    'User-Agent': 'Mozilla/5.0',
}
cookie = { "aws-priv":"eyJ2IjoxLCJldSI6MCwic3QiOjB9",
            "aws-target-static-id":"1587569651066-970706",
            "aws-target-data":"%7B%22support%22%3A%221%22%7D",
            "s_fid":"7578A7B9AE9A271E-351A1FB688F37844",
            "regStatus":"pre-register",
            "session-id":"145-1968745-9117905",
            "session-id-time":"2082787201l",
            "ubid-main":"133-9739132-8321040",
            "x-wl-uid":"1wK8h4AyfHZohWVMDWucP3tea2HjGuMvXVbkRvCR0UXrFtw7fdvQIeIf4PdGLe9453YhuZPsfZno=",
            "session-token":"",
            "aws_lang":"tw",
            "s_vn":"1619105651863%26vn%3D2",
            "s_cc":"true",
            "aws-target-visitor-id":"1587569651072-367053.32_0",
            "s_dslv":"1591516391701",
            "s_nr":"1591516391707-Repeat",
            "lc-main":"zh_CN",
            "i18n-prefs":"TWD",
            "skin":"noskin",
            "csm-hit":"tb:PR61NHATNA7CM3CFXWN3+b-CADZZMYFPXGSN0FFZ7R4|1591519308998&t:1591519308999&adb:adblk_yes",}
proxy_id = { "http": "http://61.135.155.82:443"}
response = requests.get(url, headers=head, proxies=proxy_id, cookies=cookie)
response.encoding = response.apparent_encoding
soup = BeautifulSoup(response.text, "lxml")

# %%
i = 0
for item in soup.select("div.a-section.a-spacing-medium")[:3]:
    name = item.select("span.a-size-base-plus.a-color-base.a-text-normal")
    star = item.select("div.a-row.a-size-small > span")
    print("名稱:", name[0].text)
    print("星級:", star[0]["aria-label"])
    print("星級總數", star[1]["aria-label"])
    model = soup.select("div.s-main-slot.s-result-list.s-search-results.sg-row")
    comment_url="https://www.amazon.com/-/zh/OtterBox-COMMUTER-Case-iPhone-11/product-reviews/{}/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews".format(model)
    i+=
# Out:
# 名稱: ORIbox Case for iPhone 11, Crystal Clear Case with 4 Corners Shockproof Protection, Soft Scratch-Resistant TPU Cover for iPhone 11, 6.1 inches.
# 星級: 4.8 颗星，最多 5 颗星
# 星級總數 392
# 名稱: NAISU iPhone 11 Case Liquid Silicone Latex Ultra Soft Slim Thin Translucent Gel Rubber Matte Cover Case with Scratch Resistant Back Cover for iPhone 11 6.1 Inch (Baby-Skin Feel),Dark Green
# 星級: 4.5 颗星，最多 5 颗星
# 星級總數 9
# 名稱: Kocuos iPhone 11 Case Anti-Scratch & Fingerprint & Microfiber Liner Shock Absorption Gel Rubber Full Body Protection Liquid Silicone Case for iPhone 11 6.1 inch (Lavender Grey)
# 星級: 4.5 颗星，最多 5 颗星
# 星級總數 129
